# %% [markdown]
# # Pillow and OpenCV

# %%
from PIL import Image
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img1= Image.open("Luff2.jpg")
img2= cv.imread("Luff2.jpg")

# %%
img1.show()

# %%
plt.imshow(img2)

# %%
plt.show()
